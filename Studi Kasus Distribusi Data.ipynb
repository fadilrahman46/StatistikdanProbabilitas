# %%
#import library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#bangkitkan data waktu pengiriman
# Parameter distribusi
mean = 5  # rata-rata waktu pengiriman
std_dev = 2  # standar deviasi
sample_size = 1000  # jumlah sampel

# Bangkitkan data waktu pengiriman
delivery_times = np.random.normal(mean, std_dev, sample_size)

# Buat DataFrame
df = pd.DataFrame(delivery_times, columns=['Waktu Pengiriman (hari)'])

# Tampilkan 5 baris pertama
print(df.head())
# Out:
#    Waktu Pengiriman (hari)
# 0                 1.844995
# 1                 2.960622
# 2                 4.542381
# 3                 1.799218
# 4                 6.041086

# %%
#Visualisasi Distribusi Waktu Pengiriman
# Plot histogram
plt.figure(figsize=(8, 6))
sns.histplot(df['Waktu Pengiriman (hari)'], kde=True, color='blue')
plt.title('Distribusi Waktu Pengiriman Paket')
plt.xlabel('Waktu Pengiriman (hari)')
plt.ylabel('Frekuensi')
plt.show()

# %%
#Hitung Probabilitas
# Probabilitas waktu pengiriman kurang dari 3 hari
prob_less_than_3 = np.sum(df['Waktu Pengiriman (hari)'] < 3) / sample_size
print(f"Probabilitas waktu pengiriman kurang dari 3 hari: {prob_less_than_3:.2f}")

# Probabilitas waktu pengiriman antara 4 dan 7 hari
prob_between_4_and_7 = np.sum((df['Waktu Pengiriman (hari)'] >= 4) & (df['Waktu Pengiriman (hari)'] <= 7)) / sample_size
print(f"Probabilitas waktu pengiriman antara 4 dan 7 hari: {prob_between_4_and_7:.2f}")
# Out:
# Probabilitas waktu pengiriman kurang dari 3 hari: 0.15
# Probabilitas waktu pengiriman antara 4 dan 7 hari: 0.54

# %%
#Visualisasi Probabilitas Kumulatif
# Plot CDF
plt.figure(figsize=(8, 6))
sns.ecdfplot(df['Waktu Pengiriman (hari)'], color='green')
plt.title('Probabilitas Kumulatif Waktu Pengiriman')
plt.xlabel('Waktu Pengiriman (hari)')
plt.ylabel('Probabilitas Kumulatif')
plt.show()

# %%
#Analisis Statistik Deskriptif
print(df['Waktu Pengiriman (hari)'].describe())
# Out:
# count    1000.000000
# mean        5.023280
# std         2.017353
# min        -1.568391
# 25%         3.697161
# 50%         5.075645
# 75%         6.461953
# max        11.157181
# Name: Waktu Pengiriman (hari), dtype: float64

# %% [markdown]
# #H1 Studi kasus distribusi tinggi badan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Parameter distribusi
mean = 170  # rata-rata tinggi badan
std_dev = 10  # standar deviasi
sample_size = 1000  # jumlah sampel

# Bangkitkan data tinggi badan
heights = np.random.normal(mean, std_dev, sample_size)

# Buat DataFrame
df = pd.DataFrame(heights, columns=['Tinggi Badan'])

# Tampilkan 5 baris pertama
print(df.head())

# Plot histogram
plt.figure(figsize=(8, 6))
sns.histplot(df['Tinggi Badan'], kde=True, color='blue')
plt.title('Distribusi Tinggi Badan dalam Populasi')
plt.xlabel('Tinggi Badan (cm)')
plt.ylabel('Frekuensi')
plt.show()

# Hitung probabilitas
prob = np.sum((df['Tinggi Badan'] >= 160) & (df['Tinggi Badan'] <= 180)) / sample_size
print(f"Probabilitas tinggi badan antara 160 cm dan 180 cm: {prob:.2f}")

# Plot CDF
plt.figure(figsize=(8, 6))
sns.ecdfplot(df['Tinggi Badan'], color='green')
plt.title('Probabilitas Kumulatif Tinggi Badan')
plt.xlabel('Tinggi Badan (cm)')
plt.ylabel('Probabilitas Kumulatif')
plt.show()

# Statistik deskriptif
print(df['Tinggi Badan'].describe())
# Out:
#    Tinggi Badan
# 0    173.424445
# 1    165.365891
# 2    174.972061
# 3    148.373363
# 4    164.931214
# Probabilitas tinggi badan antara 160 cm dan 180 cm: 0.66
# count    1000.000000
# mean      170.357182
# std        10.174468
# min       133.903323
# 25%       163.525130
# 50%       170.659823
# 75%       176.887116
# max       201.309051
# Name: Tinggi Badan, dtype: float64
